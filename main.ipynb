# %% [markdown]
# ## Download the Adult dataset

# %%
# !python utils/download_and_process_datasets.py  # download and process the datasets
# Out:
# Start processing dataset adult from UCI.
# Already downloaded.
# Spliting Trainig and Testing data for adult is done.
# Training data shape: (22792, 15), Testing data shape: (9769, 15)
# Training data saved at datasets/adult/train.csv, Testing data saved at datasets/adult/test.csv.

# %% [markdown]
# ## Datasets and preprocessing

# %%
from utils.utils import Preprocessor

# %%
prepper = Preprocessor("adult")

# INSERT YOUR CODE HERE

# %% [markdown]
# ## Training

# %%
#!PYTHONPATH=. python src/train.py --save True
# Out:
# Training: 100%|██████████████████| 1000/1000 [07:17<00:00,  2.29it/s, loss=6.6]

# %%
#!PYTHONPATH=. python src/train.py --save True --alignDIC True
# Out:
# Training: 100%|█████████████████| 1000/1000 [07:30<00:00,  2.22it/s, loss=5.74]

# %% [markdown]
# ## Sampling

# %%
#!PYTHONPATH=. python src/sample.py   # --alignDIC True
# Out:
# starting sampling..
# Sampling: 100%|████████████████████████████| 499/499 [00:43<00:00, 11.51step/s]
# saved to distribution_plots_False.png
